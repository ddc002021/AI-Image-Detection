# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive') #/My Drive/Colab Notebooks/imagenet
# Out:
# Mounted at /content/drive

# %%
# Dany's Directory
# %cd /content/drive/My Drive/Colab Notebooks/imagenet/

# %%
# Christopher's directory
# %cd /content/drive/My Drive/imagenet/
# Out:
# /content/drive/.shortcut-targets-by-id/1cZ-V95iJX2lZXKQeHjcbONaKRVlwKagP/imagenet

# %%
# %cd /content/drive/My Drive/imagenet/

# %%
# %cd /content/drive/MyDrive/imagenet

# %% [markdown]
# # Import Libraries

# %%
import os
import cv2
import shutil
import random
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# !pip install tensorflow --q

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #  Moving the Data

# %%
# Sample images and move them to the proper directories
random.seed(42)
src_path = os.getcwd()

# %% [markdown]
# # Inspecting the Data

# %%
training_path = os.getcwd() + '/preliminary_model_testing_data/train'
validation_path = os.getcwd() + '/preliminary_model_testing_data/validation'
testing_path = os.getcwd() + '/preliminary_model_testing_data/test'

# %%
# Create Image Data Generator instance
data_generator = ImageDataGenerator() # rescale=1.0/255.0, featurewise_center=True, horizontal_flip=True, brightness_range=[0.7,1.3], zoom_range=[0.7, 1.3], shear_range = 0.2,

# Create training iterator, validation iterator & testing iterator
train_it = data_generator.flow_from_directory(training_path,
                                              class_mode="binary",
                                              batch_size=32,
                                              target_size = (224, 224))

validation_it = data_generator.flow_from_directory(validation_path,
                                                   class_mode="binary",
                                                   batch_size=16,
                                                   target_size = (224, 224))

test_it = data_generator.flow_from_directory(testing_path,
                                             class_mode="binary",
                                             batch_size=16,
                                             target_size = (224, 224),)

batchX, batchY = train_it.next()
print("BatchX shape: {}, min: {}, max: {}".format(batchX.shape, batchX.min(), batchX.max()))
print("BatchY shape: {}".format(batchY.shape))
# Out:
# Found 4000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# BatchX shape: (32, 224, 224, 3), min: 0.0, max: 255.0
# BatchY shape: (32,)

# %% [markdown]
# # InceptionV3

# %%
# Re-size all the images to this
IMAGE_SIZE = [224, 224] # The ResNet50 model was originally trained on images of this size from the ImageNet dataset.

# %%
inception_v3 = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False) # include_top=False indicates that the final classification layer of the original ResNet50 model should not be included because the original ResNet50 model was trained to classify images into 1000 different classes from the ImageNet dataset. So, we need to add our own custom classification layer(s) later.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
for layer in inception_v3.layers:
    layer.trainable = False # freeze the weights of all layers in the ResNet50 base model, making them non-trainable during the training process.

# %%
x = Flatten()(inception_v3.output)
# Most neural network architectures, including ResNet50, use convolutional and pooling layers to extract spatial features from the input images. The output of these layers is typically a multi-dimensional tensor (e.g., (batch_size, height, width, channels)). However, dense layers expect a one-dimensional vector as input.
# The purpose of flattening the output tensor is to prepare it for the following dense (fully connected) layers that we will add for our binary classification task.

# %%
prediction = Dense(1, activation='sigmoid')(x) # creating a dense (fully connected) layer as the final output layer for our classification task.

# %%
# Create Model
# model = Model(inputs=resnet.input, outputs=prediction) # creating the final model architecture by combining the ResNet50 base model with the new classification layer we added
model = Model(inputs=inception_v3.input, outputs=prediction)

# %%
# Compile Model
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Callbacks
callbacks = [
    ModelCheckpoint("Models/PreliminaryTesting/InceptionV3_no_rescaling_model.h5", save_weights_only=True, save_freq=5)
]

# Fit the model with early stopping callback
history = model.fit_generator(
  train_it,
  validation_data=validation_it,
  epochs=20,
  steps_per_epoch=10,
  validation_steps=5,
  verbose=1,
  callbacks=callbacks
)
# Out:
# <ipython-input-39-2b19d81d071d>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/20
# 10/10 [==============================] - 231s 16s/step - loss: 77.3398 - accuracy: 0.5406 - val_loss: 102.2659 - val_accuracy: 0.4375
# Epoch 2/20
# 10/10 [==============================] - 91s 9s/step - loss: 48.3904 - accuracy: 0.5250 - val_loss: 40.0065 - val_accuracy: 0.5750
# Epoch 3/20
# 10/10 [==============================] - 82s 8s/step - loss: 22.2277 - accuracy: 0.6000 - val_loss: 14.6730 - val_accuracy: 0.5750
# Epoch 4/20
# 10/10 [==============================] - 98s 10s/step - loss: 25.2979 - accuracy: 0.5156 - val_loss: 27.2018 - val_accuracy: 0.5500
# Epoch 5/20
# 10/10 [==============================] - 72s 7s/step - loss: 18.8648 - accuracy: 0.5562 - val_loss: 21.2801 - val_accuracy: 0.5250
# Epoch 6/20
# 10/10 [==============================] - 91s 9s/step - loss: 12.2475 - accuracy: 0.6062 - val_loss: 14.1146 - val_accuracy: 0.5625
# Epoch 7/20
# 10/10 [==============================] - 75s 7s/step - loss: 15.2631 - accuracy: 0.5437 - val_loss: 32.5368 - val_accuracy: 0.5125
# Epoch 8/20
# 10/10 [==============================] - 71s 7s/step - loss: 24.2667 - accuracy: 0.5906 - val_loss: 16.9421 - val_accuracy: 0.5250
# Epoch 9/20
# 10/10 [==============================] - 71s 7s/step - loss: 15.2828 - accuracy: 0.6125 - val_loss: 16.9209 - val_accuracy: 0.5625
# Epoch 10/20
# 10/10 [==============================] - 65s 6s/step - loss: 13.3277 - accuracy: 0.6219 - val_loss: 21.0891 - val_accuracy: 0.6000
# Epoch 11/20
# 10/10 [==============================] - 64s 6s/step - loss: 16.7125 - accuracy: 0.5688 - val_loss: 11.7270 - val_accuracy: 0.6125
# Epoch 12/20
# 10/10 [==============================] - 69s 7s/step - loss: 12.2733 - accuracy: 0.6031 - val_loss: 12.5114 - val_accuracy: 0.5625
# Epoch 13/20
# 10/10 [==============================] - 70s 7s/step - loss: 7.9469 - accuracy: 0.6750 - val_loss: 11.7999 - val_accuracy: 0.5250
# Epoch 14/20
# 10/10 [==============================] - 69s 7s/step - loss: 8.0752 - accuracy: 0.6969 - val_loss: 14.3469 - val_accuracy: 0.5875
# Epoch 15/20
# 10/10 [==============================] - 69s 7s/step - loss: 11.6795 - accuracy: 0.6375 - val_loss: 22.0869 - val_accuracy: 0.5000
# Epoch 16/20
# 10/10 [==============================] - 67s 7s/step - loss: 9.5435 - accuracy: 0.7000 - val_loss: 16.8370 - val_accuracy: 0.6125
# Epoch 17/20
# 10/10 [==============================] - 61s 6s/step - loss: 8.6425 - accuracy: 0.6313 - val_loss: 11.7884 - val_accuracy: 0.6875
# Epoch 18/20
# 10/10 [==============================] - 69s 7s/step - loss: 5.7260 - accuracy: 0.7500 - val_loss: 9.0805 - val_accuracy: 0.6125
# Epoch 19/20
# 10/10 [==============================] - 67s 7s/step - loss: 9.8263 - accuracy: 0.6375 - val_loss: 15.5942 - val_accuracy: 0.5000
# Epoch 20/20
# 10/10 [==============================] - 57s 6s/step - loss: 10.2976 - accuracy: 0.6281 - val_loss: 9.9701 - val_accuracy: 0.6625

# %%
# Plot the model's training and validation accuracy
plt.plot(history.history['accuracy'], color='blue')
plt.plot(history.history['val_accuracy'], color='red')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot the model's training and validation loss
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='red')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Testing

# %%
model.evaluate(test_it, batch_size=5)
# Out:
# 25/25 [==============================] - 115s 5s/step - loss: 11.6991 - accuracy: 0.6325
# [11.699067115783691, 0.6324999928474426]

# %%
y_pred = model.predict(test_it, batch_size=5)

# %%
from sklearn.metrics import confusion_matrix

test_Y = test_it.labels
conf_matrix = confusion_matrix(test_Y, y_pred)

print("Confusion Matrix: ")
print(conf_matrix)
