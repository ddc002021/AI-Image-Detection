# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dany's Directory
# %cd /content/drive/My Drive/Colab Notebooks/imagenet/

# %%
# Christopher's directory
# %cd /content/drive/My Drive/imagenet/
# Out:
# /content/drive/.shortcut-targets-by-id/1cZ-V95iJX2lZXKQeHjcbONaKRVlwKagP/imagenet

# %% [markdown]
# # Import Libraries

# %%
import os
import cv2
import shutil
import random
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# !pip install tensorflow --q

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# #  Moving the Data

# %%
# Sample images and move them to the proper directories
random.seed(42)
src_path = os.getcwd()

# %% [markdown]
# # Read Data

# %%
training_path = os.getcwd() + '/preliminary_model_testing_data/train'
validation_path = os.getcwd() + '/preliminary_model_testing_data/validation'
testing_path = os.getcwd() + '/preliminary_model_testing_data/test'

# %%
# Create Image Data Generator instance
data_generator = ImageDataGenerator() # rescale=1.0/255.0, featurewise_center=True, horizontal_flip=True, brightness_range=[0.7,1.3], zoom_range=[0.7, 1.3], shear_range = 0.2,

# Create training iterator, validation iterator & testing iterator
train_it = data_generator.flow_from_directory(training_path,
                                              class_mode="binary",
                                              batch_size=32,
                                              target_size = (224, 224))

validation_it = data_generator.flow_from_directory(validation_path,
                                                   class_mode="binary",
                                                   batch_size=16,
                                                   target_size = (224, 224))

test_it = data_generator.flow_from_directory(testing_path,
                                             class_mode="binary",
                                             batch_size=16,
                                             target_size = (224, 224),)

batchX, batchY = train_it.next()
print("BatchX shape: {}, min: {}, max: {}".format(batchX.shape, batchX.min(), batchX.max()))
print("BatchY shape: {}".format(batchY.shape))
# Out:
# Found 4000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# BatchX shape: (32, 224, 224, 3), min: 0.0, max: 255.0
# BatchY shape: (32,)

# %% [markdown]
# # ResNet50

# %%
# Re-size all the images to this
IMAGE_SIZE = [224, 224] # The ResNet50 model was originally trained on images of this size from the ImageNet dataset.

# %%
resnet = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False) # include_top=False indicates that the final classification layer of the original ResNet50 model should not be included because the original ResNet50 model was trained to classify images into 1000 different classes from the ImageNet dataset. So, we need to add our own custom classification layer(s) later.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
for layer in resnet.layers:
    layer.trainable = False # freeze the weights of all layers in the ResNet50 base model, making them non-trainable during the training process.

# %%
x = Flatten()(resnet.output)
# Most neural network architectures, including ResNet50, use convolutional and pooling layers to extract spatial features from the input images. The output of these layers is typically a multi-dimensional tensor (e.g., (batch_size, height, width, channels)). However, dense layers expect a one-dimensional vector as input.
# The purpose of flattening the output tensor is to prepare it for the following dense (fully connected) layers that we will add for our binary classification task.

# %%
prediction = Dense(1, activation='sigmoid')(x) # creating a dense (fully connected) layer as the final output layer for our classification task.

# %%
# Create Model
model = Model(inputs=resnet.input, outputs=prediction) # creating the final model architecture by combining the ResNet50 base model with the new classification layer we added

# %%
# Compile Model
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# # Load pre-saved model weights
# model.load_weights('Models/PreliminaryTesting/ResNet50_model.h5')

# %%
# Callbacks
callbacks = [
    ModelCheckpoint("Models/PreliminaryTesting/ResNet50_no_rescaling_model.h5", save_weights_only=True, save_freq=5)
]

# Fit the model with early stopping callback
history = model.fit_generator(
  train_it,
  validation_data=validation_it,
  epochs=20,
  steps_per_epoch=10,
  validation_steps=5,
  verbose=1,
  callbacks=callbacks
)
# Out:
# <ipython-input-16-2031756a6027>:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/20
# 10/10 [==============================] - 136s 10s/step - loss: 2.4586 - accuracy: 0.6250 - val_loss: 2.7124 - val_accuracy: 0.5750
# Epoch 2/20
# 10/10 [==============================] - 109s 11s/step - loss: 2.3543 - accuracy: 0.6781 - val_loss: 2.4509 - val_accuracy: 0.6875
# Epoch 3/20
# 10/10 [==============================] - 86s 9s/step - loss: 1.8927 - accuracy: 0.7563 - val_loss: 3.3885 - val_accuracy: 0.6750
# Epoch 4/20
# 10/10 [==============================] - 84s 8s/step - loss: 2.6768 - accuracy: 0.7063 - val_loss: 2.4613 - val_accuracy: 0.7000
# Epoch 5/20
# 10/10 [==============================] - 80s 8s/step - loss: 1.9992 - accuracy: 0.7531 - val_loss: 4.4699 - val_accuracy: 0.5875
# Epoch 6/20
# 10/10 [==============================] - 85s 9s/step - loss: 1.9745 - accuracy: 0.7781 - val_loss: 2.0826 - val_accuracy: 0.7250
# Epoch 7/20
# 10/10 [==============================] - 83s 8s/step - loss: 2.4209 - accuracy: 0.7906 - val_loss: 1.1151 - val_accuracy: 0.7750
# Epoch 8/20
# 10/10 [==============================] - 82s 8s/step - loss: 2.2571 - accuracy: 0.7969 - val_loss: 2.5619 - val_accuracy: 0.7125
# Epoch 9/20
# 10/10 [==============================] - 82s 8s/step - loss: 1.5515 - accuracy: 0.8531 - val_loss: 2.8118 - val_accuracy: 0.7375
# Epoch 10/20
# 10/10 [==============================] - 82s 8s/step - loss: 2.4701 - accuracy: 0.7500 - val_loss: 3.2067 - val_accuracy: 0.6875
# Epoch 11/20
# 10/10 [==============================] - 82s 8s/step - loss: 1.8316 - accuracy: 0.8281 - val_loss: 2.7814 - val_accuracy: 0.6875
# Epoch 12/20
# 10/10 [==============================] - 87s 9s/step - loss: 1.9507 - accuracy: 0.7937 - val_loss: 2.2718 - val_accuracy: 0.7875
# Epoch 13/20
# 10/10 [==============================] - 75s 8s/step - loss: 2.0132 - accuracy: 0.8125 - val_loss: 2.6189 - val_accuracy: 0.7625
# Epoch 14/20
# 10/10 [==============================] - 83s 8s/step - loss: 1.6298 - accuracy: 0.8750 - val_loss: 3.7419 - val_accuracy: 0.7375
# Epoch 15/20
# 10/10 [==============================] - 81s 8s/step - loss: 1.5407 - accuracy: 0.8813 - val_loss: 3.1084 - val_accuracy: 0.7750
# Epoch 16/20
# 10/10 [==============================] - 81s 8s/step - loss: 1.7908 - accuracy: 0.8562 - val_loss: 7.4559 - val_accuracy: 0.6000
# Epoch 17/20
# 10/10 [==============================] - 80s 8s/step - loss: 1.5411 - accuracy: 0.8594 - val_loss: 3.5980 - val_accuracy: 0.7000
# Epoch 18/20
# 10/10 [==============================] - 91s 9s/step - loss: 1.3869 - accuracy: 0.8781 - val_loss: 2.0075 - val_accuracy: 0.7750
# Epoch 19/20
# 10/10 [==============================] - 75s 7s/step - loss: 1.1446 - accuracy: 0.8844 - val_loss: 3.1848 - val_accuracy: 0.7500
# Epoch 20/20
# 10/10 [==============================] - 81s 8s/step - loss: 0.8954 - accuracy: 0.9125 - val_loss: 2.5321 - val_accuracy: 0.7500

# %%
# Plot the model's training and validation accuracy
plt.plot(history.history['accuracy'], color='blue')
plt.plot(history.history['val_accuracy'], color='red')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot the model's training and validation loss
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='red')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Testing

# %%
model.evaluate(test_it, batch_size=5)
# Out:
# 25/25 [==============================] - 89s 4s/step - loss: 6.1178 - accuracy: 0.6200
# [6.1177754402160645, 0.6200000047683716]
