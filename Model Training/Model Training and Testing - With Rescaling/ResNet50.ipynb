# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive') #/My Drive/Colab Notebooks/imagenet
# Out:
# Mounted at /content/drive

# %%
# Dany's Directory
# %cd /content/drive/My Drive/Colab Notebooks/imagenet/

# %%
# Christopher's directory
# %cd /content/drive/My Drive/imagenet/
# Out:
# /content/drive/.shortcut-targets-by-id/1cZ-V95iJX2lZXKQeHjcbONaKRVlwKagP/imagenet

# %% [markdown]
# # Import Libraries

# %%
import os
import cv2
import shutil
import random
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# !pip install tensorflow --q

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %% [markdown]
# #  Moving the Data

# %%
# Sample images and move them to the proper directories
random.seed(42)
src_path = os.getcwd()

# %% [markdown]
# # Read Data

# %%
training_path = os.getcwd() + '/preliminary_model_testing_data/train'
validation_path = os.getcwd() + '/preliminary_model_testing_data/validation'
testing_path = os.getcwd() + '/preliminary_model_testing_data/test'

# %%
# Create Image Data Generator instance
data_generator = ImageDataGenerator(rescale=1.0/255.0) # featurewise_center=True, horizontal_flip=True, brightness_range=[0.7,1.3], zoom_range=[0.7, 1.3], shear_range = 0.2,

# Create training iterator, validation iterator & testing iterator
train_it = data_generator.flow_from_directory(training_path,
                                              class_mode="binary",
                                              batch_size=32,
                                              target_size = (224, 224))

validation_it = data_generator.flow_from_directory(validation_path,
                                                   class_mode="binary",
                                                   batch_size=16,
                                                   target_size = (224, 224))

test_it = data_generator.flow_from_directory(testing_path,
                                             class_mode="binary",
                                             batch_size=16,
                                             target_size = (224, 224),)

batchX, batchY = train_it.next()
print("BatchX shape: {}, min: {}, max: {}".format(batchX.shape, batchX.min(), batchX.max()))
print("BatchY shape: {}".format(batchY.shape))
# Out:
# Found 4000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# BatchX shape: (32, 224, 224, 3), min: 0.0, max: 1.0
# BatchY shape: (32,)

# %% [markdown]
# # ResNet50

# %%
# Re-size all the images to this
IMAGE_SIZE = [224, 224] # The ResNet50 model was originally trained on images of this size from the ImageNet dataset.

# %%
resnet = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False) # include_top=False indicates that the final classification layer of the original ResNet50 model should not be included because the original ResNet50 model was trained to classify images into 1000 different classes from the ImageNet dataset. So, we need to add our own custom classification layer(s) later.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
for layer in resnet.layers:
    layer.trainable = False # freeze the weights of all layers in the ResNet50 base model, making them non-trainable during the training process.

# %%
x = Flatten()(resnet.output)
# Most neural network architectures, including ResNet50, use convolutional and pooling layers to extract spatial features from the input images. The output of these layers is typically a multi-dimensional tensor (e.g., (batch_size, height, width, channels)). However, dense layers expect a one-dimensional vector as input.
# The purpose of flattening the output tensor is to prepare it for the following dense (fully connected) layers that we will add for our binary classification task.

# %%
prediction = Dense(1, activation='sigmoid')(x) # creating a dense (fully connected) layer as the final output layer for our classification task.

# %%
# Create Model
model = Model(inputs=resnet.input, outputs=prediction) # creating the final model architecture by combining the ResNet50 base model with the new classification layer we added

# %%
# Compile Model
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# # Load pre-saved model weights
# model.load_weights('Models/PreliminaryTesting/ResNet50_model.h5')

# %%
# Callbacks
callbacks = [
    ModelCheckpoint("Models/PreliminaryTesting/ResNet50_model.h5", save_weights_only=True, save_freq=5)
]

# Fit the model with early stopping callback
history = model.fit_generator(
  train_it,
  validation_data=validation_it,
  epochs=20,
  steps_per_epoch=10,
  validation_steps=5,
  verbose=1,
  callbacks=callbacks
)
# Out:
# <ipython-input-19-61f087f39003>:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/20
# 10/10 [==============================] - 190s 13s/step - loss: 1.9374 - accuracy: 0.4938 - val_loss: 1.0401 - val_accuracy: 0.5375
# Epoch 2/20
# 10/10 [==============================] - 128s 13s/step - loss: 0.7954 - accuracy: 0.5625 - val_loss: 0.6734 - val_accuracy: 0.5875
# Epoch 3/20
# 10/10 [==============================] - 118s 12s/step - loss: 0.7567 - accuracy: 0.5562 - val_loss: 0.7057 - val_accuracy: 0.5750
# Epoch 4/20
# 10/10 [==============================] - 115s 12s/step - loss: 0.8110 - accuracy: 0.5406 - val_loss: 0.7505 - val_accuracy: 0.5625
# Epoch 5/20
# 10/10 [==============================] - 127s 13s/step - loss: 0.6845 - accuracy: 0.6187 - val_loss: 0.6110 - val_accuracy: 0.6500
# Epoch 6/20
# 10/10 [==============================] - 113s 12s/step - loss: 0.6386 - accuracy: 0.6531 - val_loss: 0.5999 - val_accuracy: 0.6500
# Epoch 7/20
# 10/10 [==============================] - 107s 11s/step - loss: 0.6592 - accuracy: 0.6375 - val_loss: 0.6043 - val_accuracy: 0.7125
# Epoch 8/20
# 10/10 [==============================] - 94s 9s/step - loss: 0.6556 - accuracy: 0.6313 - val_loss: 0.6412 - val_accuracy: 0.6250
# Epoch 9/20
# 10/10 [==============================] - 95s 9s/step - loss: 0.7018 - accuracy: 0.6000 - val_loss: 0.6949 - val_accuracy: 0.7125
# Epoch 10/20
# 10/10 [==============================] - 94s 9s/step - loss: 0.6251 - accuracy: 0.6594 - val_loss: 0.5842 - val_accuracy: 0.6375
# Epoch 11/20
# 10/10 [==============================] - 99s 10s/step - loss: 0.6900 - accuracy: 0.5969 - val_loss: 0.9394 - val_accuracy: 0.3875
# Epoch 12/20
# 10/10 [==============================] - 95s 10s/step - loss: 0.7624 - accuracy: 0.6187 - val_loss: 0.6108 - val_accuracy: 0.6000
# Epoch 13/20
# 10/10 [==============================] - 97s 9s/step - loss: 0.6836 - accuracy: 0.6062 - val_loss: 0.5279 - val_accuracy: 0.7750
# Epoch 14/20
# 10/10 [==============================] - 97s 10s/step - loss: 0.6630 - accuracy: 0.6625 - val_loss: 0.7206 - val_accuracy: 0.5500
# Epoch 15/20
# 10/10 [==============================] - 95s 10s/step - loss: 0.7592 - accuracy: 0.5625 - val_loss: 0.6406 - val_accuracy: 0.6625
# Epoch 16/20
# 10/10 [==============================] - 98s 10s/step - loss: 0.6922 - accuracy: 0.6469 - val_loss: 1.0171 - val_accuracy: 0.4375
# Epoch 17/20
# 10/10 [==============================] - 95s 10s/step - loss: 0.8283 - accuracy: 0.6094 - val_loss: 0.8871 - val_accuracy: 0.5125
# Epoch 18/20
# 10/10 [==============================] - 98s 10s/step - loss: 0.6808 - accuracy: 0.5906 - val_loss: 0.6473 - val_accuracy: 0.6500
# Epoch 19/20
# 10/10 [==============================] - 95s 9s/step - loss: 0.7940 - accuracy: 0.6281 - val_loss: 0.6258 - val_accuracy: 0.6375
# Epoch 20/20
# 10/10 [==============================] - 93s 9s/step - loss: 0.6439 - accuracy: 0.6781 - val_loss: 0.8396 - val_accuracy: 0.5000

# %%
# Plot the model's training and validation accuracy
plt.plot(history.history['accuracy'], color='blue')
plt.plot(history.history['val_accuracy'], color='red')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot the model's training and validation loss
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='red')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Testing

# %%
model.evaluate(test_it, batch_size=5)
# Out:
# 25/25 [==============================] - 111s 4s/step - loss: 0.8301 - accuracy: 0.5900
# [0.8300839066505432, 0.5899999737739563]

# %%
y_pred = model.predict(test_it, batch_size=5)

# %%
from sklearn.metrics import confusion_matrix

test_Y = test_it.labels
conf_matrix = confusion_matrix(test_Y, y_pred)

print("Confusion Matrix: ")
print(conf_matrix)
