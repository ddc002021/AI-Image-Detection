# %% [markdown]
# # Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dany's Directory
# %cd /content/drive/My Drive/Colab Notebooks/imagenet/
# Out:
# /content/drive/My Drive/Colab Notebooks/imagenet

# %%
# Christopher's directory
# %cd /content/drive/My Drive/imagenet/
# Out:
# /content/drive/.shortcut-targets-by-id/1cZ-V95iJX2lZXKQeHjcbONaKRVlwKagP/imagenet

# %% [markdown]
# # Import Libraries

# %%
import os
import cv2
import shutil
import random
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# !pip install tensorflow --q

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# #  Moving the Data

# %%
# Sample images and move them to the proper directories
random.seed(42)
src_path = os.getcwd()

# %% [markdown]
# # Inspecting the Data

# %%
training_path = os.getcwd() + '/preliminary_model_testing_data/train'
validation_path = os.getcwd() + '/preliminary_model_testing_data/validation'
testing_path = os.getcwd() + '/preliminary_model_testing_data/test'

# %%
# Create Image Data Generator instance
data_generator = ImageDataGenerator(rescale=1.0/255.0) # rescale=1.0/255.0, featurewise_center=True, horizontal_flip=True, brightness_range=[0.7,1.3], zoom_range=[0.7, 1.3], shear_range = 0.2,

# Create training iterator, validation iterator & testing iterator
train_it = data_generator.flow_from_directory(training_path,
                                              class_mode="binary",
                                              batch_size=32,
                                              target_size = (224, 224))

validation_it = data_generator.flow_from_directory(validation_path,
                                                   class_mode="binary",
                                                   batch_size=16,
                                                   target_size = (224, 224))

test_it = data_generator.flow_from_directory(testing_path,
                                             class_mode="binary",
                                             batch_size=16,
                                             target_size = (224, 224))

batchX, batchY = train_it.next()
print("BatchX shape: {}, min: {}, max: {}".format(batchX.shape, batchX.min(), batchX.max()))
print("BatchY shape: {}".format(batchY.shape))
# Out:
# Found 4000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Found 400 images belonging to 2 classes.
# BatchX shape: (32, 224, 224, 3), min: 0.0, max: 1.0
# BatchY shape: (32,)

# %% [markdown]
# # VGG19

# %%
# Re-size all the images to this
IMAGE_SIZE = [224, 224] # The ResNet50 model was originally trained on images of this size from the ImageNet dataset.

# %%
vgg = VGG19(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False) # include_top=False indicates that the final classification layer of the original ResNet50 model should not be included because the original ResNet50 model was trained to classify images into 1000 different classes from the ImageNet dataset. So, we need to add our own custom classification layer(s) later.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
    layer.trainable = False # freeze the weights of all layers in the ResNet50 base model, making them non-trainable during the training process.

# %%
x = Flatten()(vgg.output)
# Most neural network architectures, including ResNet50, use convolutional and pooling layers to extract spatial features from the input images. The output of these layers is typically a multi-dimensional tensor (e.g., (batch_size, height, width, channels)). However, dense layers expect a one-dimensional vector as input.
# The purpose of flattening the output tensor is to prepare it for the following dense (fully connected) layers that we will add for our binary classification task.

# %%
prediction = Dense(1, activation='sigmoid')(x) # creating a dense (fully connected) layer as the final output layer for our classification task.

# %%
# Create Model
# model = Model(inputs=resnet.input, outputs=prediction) # creating the final model architecture by combining the ResNet50 base model with the new classification layer we added
model = Model(inputs=vgg.input, outputs=prediction)

# %%
# Compile Model
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Callbacks
callbacks = [
    ModelCheckpoint("Models/PreliminaryTesting/VGG19_model.h5", save_weights_only=True, save_freq=5)
]

# Fit the model with early stopping callback
history = model.fit_generator(
  train_it,
  validation_data=validation_it,
  epochs=20,
  steps_per_epoch=10,
  validation_steps=5,
  verbose=1,
  callbacks=callbacks
)
# Out:
# <ipython-input-16-91694cdb1b0b>:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/20
# 10/10 [==============================] - 416s 33s/step - loss: 0.8811 - accuracy: 0.5312 - val_loss: 0.6204 - val_accuracy: 0.6500
# Epoch 2/20
# 10/10 [==============================] - 320s 32s/step - loss: 0.6917 - accuracy: 0.6313 - val_loss: 0.6314 - val_accuracy: 0.6500
# Epoch 3/20
# 10/10 [==============================] - 307s 31s/step - loss: 0.5955 - accuracy: 0.6781 - val_loss: 0.6807 - val_accuracy: 0.6500
# Epoch 4/20
# 10/10 [==============================] - 300s 30s/step - loss: 0.6021 - accuracy: 0.6969 - val_loss: 0.6252 - val_accuracy: 0.7000
# Epoch 5/20
# 10/10 [==============================] - 316s 32s/step - loss: 0.5855 - accuracy: 0.6906 - val_loss: 0.6727 - val_accuracy: 0.6875
# Epoch 6/20
# 10/10 [==============================] - 317s 32s/step - loss: 0.5021 - accuracy: 0.7500 - val_loss: 0.6072 - val_accuracy: 0.7250
# Epoch 7/20
# 10/10 [==============================] - 321s 33s/step - loss: 0.6003 - accuracy: 0.6906 - val_loss: 0.5965 - val_accuracy: 0.7125
# Epoch 8/20
# 10/10 [==============================] - 292s 30s/step - loss: 0.5048 - accuracy: 0.7406 - val_loss: 0.5003 - val_accuracy: 0.7750
# Epoch 9/20
# 10/10 [==============================] - 294s 30s/step - loss: 0.5317 - accuracy: 0.7406 - val_loss: 0.5672 - val_accuracy: 0.7375
# Epoch 10/20
# 10/10 [==============================] - 304s 31s/step - loss: 0.4895 - accuracy: 0.7531 - val_loss: 0.5150 - val_accuracy: 0.7000
# Epoch 11/20
# 10/10 [==============================] - 304s 31s/step - loss: 0.4413 - accuracy: 0.7781 - val_loss: 0.5341 - val_accuracy: 0.7250
# Epoch 12/20
# 10/10 [==============================] - 297s 30s/step - loss: 0.4435 - accuracy: 0.7844 - val_loss: 0.7192 - val_accuracy: 0.6625
# Epoch 13/20
# 10/10 [==============================] - 326s 34s/step - loss: 0.4292 - accuracy: 0.8188 - val_loss: 0.4956 - val_accuracy: 0.7250
# Epoch 14/20
# 10/10 [==============================] - 323s 33s/step - loss: 0.4024 - accuracy: 0.8156 - val_loss: 0.6523 - val_accuracy: 0.7000
# Epoch 15/20
# 10/10 [==============================] - 325s 34s/step - loss: 0.4736 - accuracy: 0.7750 - val_loss: 0.5792 - val_accuracy: 0.6625
# Epoch 16/20
# 10/10 [==============================] - 321s 33s/step - loss: 0.4686 - accuracy: 0.7688 - val_loss: 0.3925 - val_accuracy: 0.7625
# Epoch 17/20
# 10/10 [==============================] - 301s 31s/step - loss: 0.3794 - accuracy: 0.8406 - val_loss: 0.5461 - val_accuracy: 0.7000
# Epoch 18/20
# 10/10 [==============================] - 315s 32s/step - loss: 0.4047 - accuracy: 0.7969 - val_loss: 0.4979 - val_accuracy: 0.7625
# Epoch 19/20
# 10/10 [==============================] - 302s 31s/step - loss: 0.4633 - accuracy: 0.7969 - val_loss: 0.7019 - val_accuracy: 0.6375
# Epoch 20/20
# 10/10 [==============================] - 291s 30s/step - loss: 0.4515 - accuracy: 0.7688 - val_loss: 0.7471 - val_accuracy: 0.6500

# %%
# Plot the model's training and validation accuracy
plt.plot(history.history['accuracy'], color='blue')
plt.plot(history.history['val_accuracy'], color='red')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plot the model's training and validation loss
plt.plot(history.history['loss'], color='blue')
plt.plot(history.history['val_loss'], color='red')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Model Testing

# %%
model.evaluate(test_it, batch_size=5)
# Out:
# 25/25 [==============================] - 290s 12s/step - loss: 0.9069 - accuracy: 0.5900
# [0.9069393277168274, 0.5899999737739563]

# %%
y_pred = model.predict(test_it, batch_size=5)

# %%
from sklearn.metrics import confusion_matrix

test_Y = test_it.labels
y_pred_binary = (y_pred > 0.5).astype(int)

conf_matrix = confusion_matrix(test_Y, y_pred_binary)

print("Confusion Matrix: ")
print(conf_matrix)
